# %%
import requests

def data_from_api_id(reform_id: int):
    res = requests.get(f"https://api.policyengine.org/us/economy/{reform_id}/over/2?time_period=2024&region=enhanced_us")
    return res.json()

data_from_api_id(42528)
# Out:
# {'average_time': 409.58776500000005,
#  'message': None,
#  'result': {'budget': {'baseline_net_income': 11960630947679.889,
#    'benefit_spending_impact': 1169673562248.731,
#    'budgetary_impact': -109166760152.6289,
#    'households': 134663334.54167563,
#    'state_tax_revenue_impact': 0.0,
#    'tax_revenue_impact': 1131933078905.563},
#   'decile': {'average': {'1': 4677.5965056487585,
#     '10': 23399.71125277354,
#     '2': 1318.4630378932343,
#     '3': 281.9501444090257,
#     '4': -466.9677419570688,
#     '5': -1738.7729370387399,
#     '6': -3216.6648990633175,
#     '7': -5284.7753767844215,
#     '8': -5765.944413506424,
#     '9': -6680.1959579892755},
#    'relative': {'1': 1.559446679894423,
#     '10': 0.05043307062346011,
#     '2': 0.040940282908047396,
#     '3': 0.0064152358468877076,
#     '4': -0.00860283570212126,
#     '5': -0.02679921900930625,
#     '6': -0.04171476732729049,
#     '7': -0.05696934044489541,
#     '8': -0.05059999634955719,
# ...
